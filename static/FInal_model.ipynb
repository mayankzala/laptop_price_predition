# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('final_data.csv')

# %%
data.head()
# Out:
#    Unnamed: 0    id                                         name  \
# 0           0  2881                   Msi Katana GF76 11UC-655NL
# 1           1  6204                            Apple Macbook Pro
# 2           2  6268                          Medion Akoya E15413
# 3           3  6205                     Microsoft Surface Book 3
# 4           4   692  Asus Rog Zephyrus G14 GA402RJ-L8018W 6900HS
#
#                mpn                                              url_1  \
# 0   9S7-17L212-655  https://www.bol.com/be/nl/p/msi-katana-gf76-11...
# 1        MKGR3LL/A  https://www.bestbuy.com/site/macbook-pro-14-la...
# 2         30034235  https://azerty.nl/product/e15413-i5-512f8-qwer...
# 3        SMN-00001  https://www.bestbuy.com/site/microsoft-surface...
# 4  90NR09T4-M00430  https://www.bol.com/be/nl/p/asus-rog-zephyrus-...
#
#    price_1  old_price_1 currency_1  \
# 0  1271.00       999.00        EUR
# 1  1599.00          NaN        USD
# 2   792.95       758.74        EUR
# ...

# %%
data=data.drop(columns=['Unnamed: 0'])

# %%
data.head()
# Out:
#      id                                         name              mpn  \
# 0  2881                   Msi Katana GF76 11UC-655NL   9S7-17L212-655
# 1  6204                            Apple Macbook Pro        MKGR3LL/A
# 2  6268                          Medion Akoya E15413         30034235
# 3  6205                     Microsoft Surface Book 3        SMN-00001
# 4   692  Asus Rog Zephyrus G14 GA402RJ-L8018W 6900HS  90NR09T4-M00430
#
#                                                url_1  price_1  old_price_1  \
# 0  https://www.bol.com/be/nl/p/msi-katana-gf76-11...  1271.00       999.00
# 1  https://www.bestbuy.com/site/macbook-pro-14-la...  1599.00          NaN
# 2  https://azerty.nl/product/e15413-i5-512f8-qwer...   792.95       758.74
# 3  https://www.bestbuy.com/site/microsoft-surface...  2519.99          NaN
# 4  https://www.bol.com/be/nl/p/asus-rog-zephyrus-...  2114.00          NaN
#
#   currency_1                                               info  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6857 entries, 0 to 6856
# Data columns (total 55 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      6857 non-null   int64
#  1   name                    6857 non-null   object
#  2   mpn                     6857 non-null   object
#  3   url_1                   6857 non-null   object
#  4   price_1                 6597 non-null   float64
#  5   old_price_1             4784 non-null   float64
#  6   currency_1              6857 non-null   object
#  7   info                    6852 non-null   object
#  8   cpu_type_1              6842 non-null   object
#  9   cpu_implementation_1    6275 non-null   object
#  10  cpu_number_of_cores_1   5789 non-null   float64
#  11  display_size__inch_1    6842 non-null   float64
#  12  memory_ram__gb_1        6836 non-null   float64
#  13  storage_type_1          6803 non-null   object
# ...

# %%
data=data.drop(columns=['url_1','url_2','url_3','url_4','url_5','url_6','url_7','url_8','url_9','url_10','url_11','url_12'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6857 entries, 0 to 6856
# Data columns (total 43 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      6857 non-null   int64
#  1   name                    6857 non-null   object
#  2   mpn                     6857 non-null   object
#  3   price_1                 6597 non-null   float64
#  4   old_price_1             4784 non-null   float64
#  5   currency_1              6857 non-null   object
#  6   info                    6852 non-null   object
#  7   cpu_type_1              6842 non-null   object
#  8   cpu_implementation_1    6275 non-null   object
#  9   cpu_number_of_cores_1   5789 non-null   float64
#  10  display_size__inch_1    6842 non-null   float64
#  11  memory_ram__gb_1        6836 non-null   float64
#  12  storage_type_1          6803 non-null   object
#  13  storage_capacity__gb_1  6831 non-null   float64
# ...

# %%
data=data.drop(columns=['price_2','old_price_2','currency_2','price_3','old_price_3','currency_3','price_4','old_price_4','currency_4','price_5','old_price_5','currency_5','price_6','old_price_6','currency_6','price_7','old_price_7','currency_7','price_8','old_price_8','currency_8','price_9','old_price_9','currency_9','price_10','old_price_10','currency_10','price_2','old_price_2','currency_2',])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6857 entries, 0 to 6856
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      6857 non-null   int64
#  1   name                    6857 non-null   object
#  2   mpn                     6857 non-null   object
#  3   price_1                 6597 non-null   float64
#  4   old_price_1             4784 non-null   float64
#  5   currency_1              6857 non-null   object
#  6   info                    6852 non-null   object
#  7   cpu_type_1              6842 non-null   object
#  8   cpu_implementation_1    6275 non-null   object
#  9   cpu_number_of_cores_1   5789 non-null   float64
#  10  display_size__inch_1    6842 non-null   float64
#  11  memory_ram__gb_1        6836 non-null   float64
#  12  storage_type_1          6803 non-null   object
#  13  storage_capacity__gb_1  6831 non-null   float64
# ...

# %%
data.head()
# Out:
#      id                                         name              mpn  \
# 0  2881                   Msi Katana GF76 11UC-655NL   9S7-17L212-655
# 1  6204                            Apple Macbook Pro        MKGR3LL/A
# 2  6268                          Medion Akoya E15413         30034235
# 3  6205                     Microsoft Surface Book 3        SMN-00001
# 4   692  Asus Rog Zephyrus G14 GA402RJ-L8018W 6900HS  90NR09T4-M00430
#
#    price_1  old_price_1 currency_1  \
# 0  1271.00       999.00        EUR
# 1  1599.00          NaN        USD
# 2   792.95       758.74        EUR
# 3  2519.99          NaN        USD
# 4  2114.00          NaN        EUR
#
#                                                 info  \
# 0  Intel Core i7 - i7-11800H - 8 cores - 17.3 inc...
# 1  2021 - Apple M1 Pro - Apple M1 Pro - 8 cores -...
# 2  Intel® Core™ i5 - i5-1235U - 10 cores - 15.6 i...
# 3  2020 - Intel 10th Generation Core i7 - 1065G7 ...
# 4  AMD Ryzen™ 9 - 6900HS - 8 cores - 14 inch - 16...
#
# ...

# %%
# data=data.drop(columns=['info'])

# %%
data=data.drop(columns=['general_year_1'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6857 entries, 0 to 6856
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      6857 non-null   int64
#  1   name                    6857 non-null   object
#  2   mpn                     6857 non-null   object
#  3   price_1                 6597 non-null   float64
#  4   old_price_1             4784 non-null   float64
#  5   currency_1              6857 non-null   object
#  6   info                    6852 non-null   object
#  7   cpu_type_1              6842 non-null   object
#  8   cpu_implementation_1    6275 non-null   object
#  9   cpu_number_of_cores_1   5789 non-null   float64
#  10  display_size__inch_1    6842 non-null   float64
#  11  memory_ram__gb_1        6836 non-null   float64
#  12  storage_type_1          6803 non-null   object
#  13  storage_capacity__gb_1  6831 non-null   float64
# ...

# %%
data.isnull().sum()
# Out:
# id                           0
# name                         0
# mpn                          0
# price_1                    260
# old_price_1               2073
# currency_1                   0
# info                         5
# cpu_type_1                  15
# cpu_implementation_1       582
# cpu_number_of_cores_1     1068
# display_size__inch_1        15
# memory_ram__gb_1            21
# storage_type_1              54
# storage_capacity__gb_1      26
# design_color_name_1         26
# dtype: int64

# %%
# data.count()

# %%
data=data.dropna(subset=['old_price_1'])

# %%
data.isnull().sum()
# Out:
# id                          0
# name                        0
# mpn                         0
# price_1                   239
# old_price_1                 0
# currency_1                  0
# info                        4
# cpu_type_1                  9
# cpu_implementation_1      310
# cpu_number_of_cores_1     569
# display_size__inch_1        9
# memory_ram__gb_1           16
# storage_type_1             31
# storage_capacity__gb_1     20
# design_color_name_1        17
# dtype: int64

# %%
data=data.dropna(subset=['price_1'])

# %%
data.isnull().sum()
# Out:
# id                          0
# name                        0
# mpn                         0
# price_1                     0
# old_price_1                 0
# currency_1                  0
# info                        3
# cpu_type_1                  8
# cpu_implementation_1      309
# cpu_number_of_cores_1     534
# display_size__inch_1        8
# memory_ram__gb_1           15
# storage_type_1             30
# storage_capacity__gb_1     19
# design_color_name_1        16
# dtype: int64

# %%
data.count()
# Out:
# id                        4545
# name                      4545
# mpn                       4545
# price_1                   4545
# old_price_1               4545
# currency_1                4545
# info                      4542
# cpu_type_1                4537
# cpu_implementation_1      4236
# cpu_number_of_cores_1     4011
# display_size__inch_1      4537
# memory_ram__gb_1          4530
# storage_type_1            4515
# storage_capacity__gb_1    4526
# design_color_name_1       4529
# dtype: int64

# %%
data=data.dropna()

# %%
data.isnull().sum()
# Out:
# id                        0
# name                      0
# mpn                       0
# price_1                   0
# old_price_1               0
# currency_1                0
# info                      0
# cpu_type_1                0
# cpu_implementation_1      0
# cpu_number_of_cores_1     0
# display_size__inch_1      0
# memory_ram__gb_1          0
# storage_type_1            0
# storage_capacity__gb_1    0
# design_color_name_1       0
# dtype: int64

# %%
data.info()  #this is our final dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3720 entries, 0 to 6855
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      3720 non-null   int64
#  1   name                    3720 non-null   object
#  2   mpn                     3720 non-null   object
#  3   price_1                 3720 non-null   float64
#  4   old_price_1             3720 non-null   float64
#  5   currency_1              3720 non-null   object
#  6   info                    3720 non-null   object
#  7   cpu_type_1              3720 non-null   object
#  8   cpu_implementation_1    3720 non-null   object
#  9   cpu_number_of_cores_1   3720 non-null   float64
#  10  display_size__inch_1    3720 non-null   float64
#  11  memory_ram__gb_1        3720 non-null   float64
#  12  storage_type_1          3720 non-null   object
#  13  storage_capacity__gb_1  3720 non-null   float64
# ...

# %%
data.head()
# Out:
#      id                                      name                         mpn  \
# 0  2881                Msi Katana GF76 11UC-655NL              9S7-17L212-655
# 2  6268                       Medion Akoya E15413                    30034235
# 5   693  Msi Creator Z16P B12UGST-019BE i9-12900H  CREATOR Z16P B12UGST-019BE
# 6  4165                      Msi PULSE GL66 12UEK              GL6612UEK021NL
# 7   830                           Lenovo Legion 7                  82N600MWMB
#
#    price_1  old_price_1 currency_1  \
# 0  1271.00       999.00        EUR
# 2   792.95       758.74        EUR
# 5  3549.00      3662.71        EUR
# 6  1699.00      1699.01        EUR
# 7  2999.00      2980.60        EUR
#
#                                                 info       cpu_type_1  \
# 0  Intel Core i7 - i7-11800H - 8 cores - 17.3 inc...    Intel Core i7
# 2  Intel® Core™ i5 - i5-1235U - 10 cores - 15.6 i...  Intel® Core™ i5
# ...

# %%
data['currency_1'].value_counts()
# Out:
# EUR    3482
# USD     238
# Name: currency_1, dtype: int64

# %%
data=data.drop(columns=['old_price_1'])

# %%
data['price']=data.apply(lambda x:x['price_1']*90.56 if x['currency_1']=='EUR' else x['price_1']*81.94 ,axis=1)

# %%
data.head()
# Out:
#      id                                      name                         mpn  \
# 0  2881                Msi Katana GF76 11UC-655NL              9S7-17L212-655
# 2  6268                       Medion Akoya E15413                    30034235
# 5   693  Msi Creator Z16P B12UGST-019BE i9-12900H  CREATOR Z16P B12UGST-019BE
# 6  4165                      Msi PULSE GL66 12UEK              GL6612UEK021NL
# 7   830                           Lenovo Legion 7                  82N600MWMB
#
#    price_1 currency_1                                               info  \
# 0  1271.00        EUR  Intel Core i7 - i7-11800H - 8 cores - 17.3 inc...
# 2   792.95        EUR  Intel® Core™ i5 - i5-1235U - 10 cores - 15.6 i...
# 5  3549.00        EUR  Intel Core i9 - i9-12900H - 14 cores - 16 inch...
# 6  1699.00        EUR  Intel® Core™ i7 - i7-12700H - 14 cores - 15.6 ...
# 7  2999.00        EUR  AMD Ryzen 9 - 5900HX - 8 cores - 16 inch - 32G...
#
# ...

# %%
data=data.drop(columns=['price_1','currency_1'])

# %%
data.head()
# Out:
#      id                                      name                         mpn  \
# 0  2881                Msi Katana GF76 11UC-655NL              9S7-17L212-655
# 2  6268                       Medion Akoya E15413                    30034235
# 5   693  Msi Creator Z16P B12UGST-019BE i9-12900H  CREATOR Z16P B12UGST-019BE
# 6  4165                      Msi PULSE GL66 12UEK              GL6612UEK021NL
# 7   830                           Lenovo Legion 7                  82N600MWMB
#
#                                                 info       cpu_type_1  \
# 0  Intel Core i7 - i7-11800H - 8 cores - 17.3 inc...    Intel Core i7
# 2  Intel® Core™ i5 - i5-1235U - 10 cores - 15.6 i...  Intel® Core™ i5
# 5  Intel Core i9 - i9-12900H - 14 cores - 16 inch...    Intel Core i9
# 6  Intel® Core™ i7 - i7-12700H - 14 cores - 15.6 ...  Intel® Core™ i7
# 7  AMD Ryzen 9 - 5900HX - 8 cores - 16 inch - 32G...      AMD Ryzen 9
#
#   cpu_implementation_1  cpu_number_of_cores_1  display_size__inch_1  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3720 entries, 0 to 6855
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      3720 non-null   int64
#  1   name                    3720 non-null   object
#  2   mpn                     3720 non-null   object
#  3   info                    3720 non-null   object
#  4   cpu_type_1              3720 non-null   object
#  5   cpu_implementation_1    3720 non-null   object
#  6   cpu_number_of_cores_1   3720 non-null   float64
#  7   display_size__inch_1    3720 non-null   float64
#  8   memory_ram__gb_1        3720 non-null   float64
#  9   storage_type_1          3720 non-null   object
#  10  storage_capacity__gb_1  3720 non-null   float64
#  11  design_color_name_1     3720 non-null   object
#  12  price                   3720 non-null   float64
# dtypes: float64(5), int64(1), object(7)
# memory usage: 406.9+ KB

# %%
data['name']=data['name'].apply(lambda x:x.split(' '))

# %%
data.head(2)
# Out:
#      id                             name             mpn  \
# 0  2881  [Msi, Katana, GF76, 11UC-655NL]  9S7-17L212-655
# 2  6268          [Medion, Akoya, E15413]        30034235
#
#                                                 info       cpu_type_1  \
# 0  Intel Core i7 - i7-11800H - 8 cores - 17.3 inc...    Intel Core i7
# 2  Intel® Core™ i5 - i5-1235U - 10 cores - 15.6 i...  Intel® Core™ i5
#
#   cpu_implementation_1  cpu_number_of_cores_1  display_size__inch_1  \
# 0            i7-11800H                    8.0                  17.3
# 2             i5-1235U                   10.0                  15.6
#
#    memory_ram__gb_1 storage_type_1  storage_capacity__gb_1  \
# 0              16.0            SSD                   512.0
# 2               8.0            SSD                   512.0
#
#   design_color_name_1       price
# 0               Black  115101.760
# 2            Metallic   71809.552

# %%
data=data[data['name'].map(len) > 1]

# %%
data.head(2)
# Out:
#      id                             name             mpn  \
# 0  2881  [Msi, Katana, GF76, 11UC-655NL]  9S7-17L212-655
# 2  6268          [Medion, Akoya, E15413]        30034235
#
#                                                 info       cpu_type_1  \
# 0  Intel Core i7 - i7-11800H - 8 cores - 17.3 inc...    Intel Core i7
# 2  Intel® Core™ i5 - i5-1235U - 10 cores - 15.6 i...  Intel® Core™ i5
#
#   cpu_implementation_1  cpu_number_of_cores_1  display_size__inch_1  \
# 0            i7-11800H                    8.0                  17.3
# 2             i5-1235U                   10.0                  15.6
#
#    memory_ram__gb_1 storage_type_1  storage_capacity__gb_1  \
# 0              16.0            SSD                   512.0
# 2               8.0            SSD                   512.0
#
#   design_color_name_1       price
# 0               Black  115101.760
# 2            Metallic   71809.552

# %%
# d=d[d.map(len) > 1]

# %%
# d.apply(lambda x:len(x)).value_counts()

# %%
data['name']=data['name'].apply(lambda x:[x[0],x[1]])

# %%
data.head()
# Out:
#      id              name                         mpn  \
# 0  2881     [Msi, Katana]              9S7-17L212-655
# 2  6268   [Medion, Akoya]                    30034235
# 5   693    [Msi, Creator]  CREATOR Z16P B12UGST-019BE
# 6  4165      [Msi, PULSE]              GL6612UEK021NL
# 7   830  [Lenovo, Legion]                  82N600MWMB
#
#                                                 info       cpu_type_1  \
# 0  Intel Core i7 - i7-11800H - 8 cores - 17.3 inc...    Intel Core i7
# 2  Intel® Core™ i5 - i5-1235U - 10 cores - 15.6 i...  Intel® Core™ i5
# 5  Intel Core i9 - i9-12900H - 14 cores - 16 inch...    Intel Core i9
# 6  Intel® Core™ i7 - i7-12700H - 14 cores - 15.6 ...  Intel® Core™ i7
# 7  AMD Ryzen 9 - 5900HX - 8 cores - 16 inch - 32G...      AMD Ryzen 9
#
#   cpu_implementation_1  cpu_number_of_cores_1  display_size__inch_1  \
# 0            i7-11800H                    8.0                  17.3
# 2             i5-1235U                   10.0                  15.6
# ...

# %%
data['company']=data['name'].apply(lambda x:x[0]).str.lower()

# %%
data['type']=data['name'].apply(lambda x:x[1]).str.lower()

# %%
data.head()
# Out:
#      id              name                         mpn  \
# 0  2881     [Msi, Katana]              9S7-17L212-655
# 2  6268   [Medion, Akoya]                    30034235
# 5   693    [Msi, Creator]  CREATOR Z16P B12UGST-019BE
# 6  4165      [Msi, PULSE]              GL6612UEK021NL
# 7   830  [Lenovo, Legion]                  82N600MWMB
#
#                                                 info       cpu_type_1  \
# 0  Intel Core i7 - i7-11800H - 8 cores - 17.3 inc...    Intel Core i7
# 2  Intel® Core™ i5 - i5-1235U - 10 cores - 15.6 i...  Intel® Core™ i5
# 5  Intel Core i9 - i9-12900H - 14 cores - 16 inch...    Intel Core i9
# 6  Intel® Core™ i7 - i7-12700H - 14 cores - 15.6 ...  Intel® Core™ i7
# 7  AMD Ryzen 9 - 5900HX - 8 cores - 16 inch - 32G...      AMD Ryzen 9
#
#   cpu_implementation_1  cpu_number_of_cores_1  display_size__inch_1  \
# 0            i7-11800H                    8.0                  17.3
# 2             i5-1235U                   10.0                  15.6
# ...

# %%
data=data.drop(columns=['mpn'])

# %%
data.head()
# Out:
#      id              name                                               info  \
# 0  2881     [Msi, Katana]  Intel Core i7 - i7-11800H - 8 cores - 17.3 inc...
# 2  6268   [Medion, Akoya]  Intel® Core™ i5 - i5-1235U - 10 cores - 15.6 i...
# 5   693    [Msi, Creator]  Intel Core i9 - i9-12900H - 14 cores - 16 inch...
# 6  4165      [Msi, PULSE]  Intel® Core™ i7 - i7-12700H - 14 cores - 15.6 ...
# 7   830  [Lenovo, Legion]  AMD Ryzen 9 - 5900HX - 8 cores - 16 inch - 32G...
#
#         cpu_type_1 cpu_implementation_1  cpu_number_of_cores_1  \
# 0    Intel Core i7            i7-11800H                    8.0
# 2  Intel® Core™ i5             i5-1235U                   10.0
# 5    Intel Core i9            i9-12900H                   14.0
# 6  Intel® Core™ i7            i7-12700H                   14.0
# 7      AMD Ryzen 9               5900HX                    8.0
#
#    display_size__inch_1  memory_ram__gb_1 storage_type_1  \
# 0                  17.3              16.0            SSD
# ...

# %%
data=data.drop(columns=['name'])
data.head(2)
# Out:
#      id                                               info       cpu_type_1  \
# 0  2881  Intel Core i7 - i7-11800H - 8 cores - 17.3 inc...    Intel Core i7
# 2  6268  Intel® Core™ i5 - i5-1235U - 10 cores - 15.6 i...  Intel® Core™ i5
#
#   cpu_implementation_1  cpu_number_of_cores_1  display_size__inch_1  \
# 0            i7-11800H                    8.0                  17.3
# 2             i5-1235U                   10.0                  15.6
#
#    memory_ram__gb_1 storage_type_1  storage_capacity__gb_1  \
# 0              16.0            SSD                   512.0
# 2               8.0            SSD                   512.0
#
#   design_color_name_1       price company    type
# 0               Black  115101.760     msi  katana
# 2            Metallic   71809.552  medion   akoya

# %%
data=data.drop(columns=['info'])
data.head(2)
# Out:
#      id       cpu_type_1 cpu_implementation_1  cpu_number_of_cores_1  \
# 0  2881    Intel Core i7            i7-11800H                    8.0
# 2  6268  Intel® Core™ i5             i5-1235U                   10.0
#
#    display_size__inch_1  memory_ram__gb_1 storage_type_1  \
# 0                  17.3              16.0            SSD
# 2                  15.6               8.0            SSD
#
#    storage_capacity__gb_1 design_color_name_1       price company    type
# 0                   512.0               Black  115101.760     msi  katana
# 2                   512.0            Metallic   71809.552  medion   akoya

# %%
data['company'].value_counts()
# Out:
# hp            1137
# lenovo         670
# asus           527
# acer           361
# msi            266
# microsoft      196
# dell           179
# apple          144
# medion          61
# getac           34
# fujitsu         33
# samsung         23
# dynabook        18
# skikk           18
# razer           17
# alienware        8
# lg               6
# jumper           5
# elementkey       4
# terra            3
# gigabyte         2
# predia           1
# asu              1
# xiaomi           1
# denver           1
# copaco           1
# corsair          1
# rangee           1
# Name: company, dtype: int64

# %%
# data['company'].value_counts().plot(kind='bar')

# %%
sns.barplot(data['company'],data['price'])
plt.xticks(rotation='vertical')
plt.show()
# Out:
# C:\Users\A to Z Infosys\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
com_list=['hp','lenovo','asus','acer','msi','microsoft','dell','apple','samsung','alienware','getac','razer']
def parse_company(text):
    if text in com_list:
        return text
    else :
        return 'other'

# %%
data['company']=data['company'].apply(parse_company)

# %%
data['company'].value_counts()
# Out:
# hp           1137
# lenovo        670
# asus          527
# acer          361
# msi           266
# microsoft     196
# dell          179
# other         157
# apple         144
# getac          34
# samsung        23
# razer          17
# alienware       8
# Name: company, dtype: int64

# %%
sns.barplot(data['company'],data['price'])
plt.xticks(rotation='vertical')
plt.show()
# Out:
# C:\Users\A to Z Infosys\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# for type
data['type'].value_counts().head(50)
# Out:
# ideapad       249
# chromebook    208
# surface       181
# thinkpad      169
# probook       154
# macbook       139
# elitebook     136
# aspire        122
# pavilion      122
# vivobook      121
# thinkbook      71
# zbook          70
# rog            69
# latitude       68
# legion         66
# envy           61
# zenbook        55
# gaming         51
# precision      48
# tuf            46
# katana         44
# travelmate     39
# expertbook     37
# victus         35
# omen           35
# lifebook       31
# akoya          30
# k12            29
# vector         28
# stealth        27
# nitro          27
# erazer         27
# elite          26
# extensa        23
# yoga           22
# b360           22
# galaxy         22
# pro            22
# specter        21
# swift          20
# xps            19
# v15            18
# creator        17
# raider         17
# 250            17
# vostro         16
# satellite      16
# predator       16
# 15s            15
# mobile         14
# ...

# %%
type_l=['ideapad','chromebook','surface','thinkpad','probook','macbook','elitebook','aspire','pavilion','vivobook','thinkbook','zbook','legion','zenbook','gaming','expertbook','victus','omen','lifebook','nitro']
def parse_type(text):
    if text in type_l:
        return text
    else :
        return 'other'

# %%
data['type']=data['type'].apply(parse_type)

# %%
data['type'].value_counts()
# Out:
# other         1640
# ideapad        249
# chromebook     208
# surface        181
# thinkpad       169
# probook        154
# macbook        139
# elitebook      136
# pavilion       122
# aspire         122
# vivobook       121
# thinkbook       71
# zbook           70
# legion          66
# zenbook         55
# gaming          51
# expertbook      37
# omen            35
# victus          35
# lifebook        31
# nitro           27
# Name: type, dtype: int64

# %%
sns.barplot(data['type'],data['price'])
plt.xticks(rotation='vertical')
plt.show()
# Out:
# C:\Users\A to Z Infosys\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.barplot(data['cpu_type_1'],data['price'])  
plt.xticks(rotation='vertical')
plt.show()
# Out:
# C:\Users\A to Z Infosys\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data.head()
# Out:
#      id       cpu_type_1 cpu_implementation_1  cpu_number_of_cores_1  \
# 0  2881    Intel Core i7            i7-11800H                    8.0
# 2  6268  Intel® Core™ i5             i5-1235U                   10.0
# 5   693    Intel Core i9            i9-12900H                   14.0
# 6  4165  Intel® Core™ i7            i7-12700H                   14.0
# 7   830      AMD Ryzen 9               5900HX                    8.0
#
#    display_size__inch_1  memory_ram__gb_1 storage_type_1  \
# 0                  17.3              16.0            SSD
# 2                  15.6               8.0            SSD
# 5                  16.0              32.0            SSD
# 6                  15.6              16.0            SSD
# 7                  16.0              32.0            SSD
#
#    storage_capacity__gb_1 design_color_name_1       price company    type
# 0                   512.0               Black  115101.760     msi   other
# ...

# %%
intel=['Intel Core i5','Intel® Core™ i5','Intel® Core™ i7','Intel Core i7','Intel Celeron','Intel Core i3','Intel® Core™ i3',
       'Intel Core i9','Intel® Celeron®','Intel Pentium','Intel® Core™ i9','Intel® Pentium® Silver',
       'Intel 12th Generation Core i7','Intel® Celeron® N','Intel 11th Generation Core i7','Intel 11th Generation Core i5',
      'Intel 12th Generation Core i5','Intel 12th Generation Core i7 Evo Platform','Intel® Pentium® Gold',
       'Intel 12th Generation Core i9',
      'Intel Atom','Intel 10th Generation Core i5','Intel 11th Generation Core i7 Evo Platform','Intel 11th Generation Core i3',
'Intel 13th Generation Core i7','Intel 10th Generation Core i3','Intel Pentium Silver','Intel 10th Generation Core i7',
'Intel 12th Generation Core i3','Intel Core M','Intel Pentium Gold','Intel® Xeon®','Intel® Core™ m3','Intel Pentium N']

amd=['AMD Ryzen 7','AMD Ryzen 5','AMD Ryzen™ 5','AMD Ryzen™ 7','AMD 3015Ce'  ,'AMD Ryzen 3','AMD Ryzen™ 3','AMD Ryzen 9',
     'AMD Ryzen 7 5000 Series','AMD Ryzen™ 9','AMD Ryzen™ 7 PRO','AMD Ryzen™ 5 PRO','AMD Ryzen 5 5000 Series',
     'AMD Athlon Silver','AMD Ryzen 9 5000 Series','AMD 3020E','AMD A4','AMD Ryzen 7 6000 Series','AMD Ryzen 9 5000 Series',
     'AMD Athlon Gold','AMD Ryzen 5 Microsoft Surface Edition','AMD Ryzen 7 Microsoft Surface Edition','AMD Ryzen™ 3 PRO',
     'AMD Ryzen™ 3 PRO','AMD 3000,','AMD Ryzen 5 5000 Series PRO,','AMD Ryzen 5 6000 Series,','AMD Athlon 300U,',
     'AMD Ryzen 5 3000 Series','AMD Athlon,','AMD Ryzen™ 9 PRO','AMD A']
apple=['Apple M', 'Apple M1', 'Apple M1 Pro', 'Apple M2 chip', 'Apple M2', 'Apple M2 Pro', 'Apple M1-chip', 
       'Apple M1 Max', 'Apple M2 Max']
def parse_cpu_type(text):
    if text in intel:
        return 'intel'
    elif text in amd :
        return 'amd'
    elif text in apple:
        return 'apple'
    else:
        return 'other'

# %%
data['cpu_type']=data['cpu_type_1'].apply(parse_cpu_type)

# %%
data['cpu_type'].value_counts()
# Out:
# intel    2622
# amd       903
# apple     134
# other      60
# Name: cpu_type, dtype: int64

# %%
data['cpu_implementation_1'].value_counts()
# Out:
# i5-1135G7    273
# i7-12700H    155
# i5-1235U     145
# 5500U        112
# i7-11800H    106
#             ...
# i7-10850H      1
# i3             1
# i5-4210M       1
# 6950H          1
# n3350          1
# Name: cpu_implementation_1, Length: 362, dtype: int64

# %%
d=data['cpu_implementation_1'].apply(lambda x:x.split('-') if x[0]=='i' else x)

# %%
d
# Out:
# 0       [i7, 11800H]
# 2        [i5, 1235U]
# 5       [i9, 12900H]
# 6       [i7, 12700H]
# 7             5900HX
#             ...
# 6850           5800H
# 6851    [i5, 1035G1]
# 6853           1255U
# 6854    Apple M2 Max
# 6855     [i5, 1235U]
# Name: cpu_implementation_1, Length: 3719, dtype: object

# %%
d=d.apply(lambda x:x[0] if isinstance(x, list) else x)

# %%
d.value_counts().head()
# Out:
# i7       801
# i5       712
# i3       161
# 5500U    112
# 5800H    106
# Name: cpu_implementation_1, dtype: int64

# %%
data.head()
# Out:
#      id       cpu_type_1 cpu_implementation_1  cpu_number_of_cores_1  \
# 0  2881    Intel Core i7            i7-11800H                    8.0
# 2  6268  Intel® Core™ i5             i5-1235U                   10.0
# 5   693    Intel Core i9            i9-12900H                   14.0
# 6  4165  Intel® Core™ i7            i7-12700H                   14.0
# 7   830      AMD Ryzen 9               5900HX                    8.0
#
#    display_size__inch_1  memory_ram__gb_1 storage_type_1  \
# 0                  17.3              16.0            SSD
# 2                  15.6               8.0            SSD
# 5                  16.0              32.0            SSD
# 6                  15.6              16.0            SSD
# 7                  16.0              32.0            SSD
#
#    storage_capacity__gb_1 design_color_name_1       price company    type  \
# 0                   512.0               Black  115101.760     msi   other
# ...

# %%
d=data['cpu_implementation_1'].value_counts()

# %%
d
# Out:
# i5-1135G7    273
# i7-12700H    155
# i5-1235U     145
# 5500U        112
# i7-11800H    106
#             ...
# i7-10850H      1
# i3             1
# i5-4210M       1
# 6950H          1
# n3350          1
# Name: cpu_implementation_1, Length: 362, dtype: int64

# %%
d=data['cpu_implementation_1'].apply(lambda x:x.split('-') if x[0]=='i' else x)

# %%
d
# Out:
# 0       [i7, 11800H]
# 2        [i5, 1235U]
# 5       [i9, 12900H]
# 6       [i7, 12700H]
# 7             5900HX
#             ...
# 6850           5800H
# 6851    [i5, 1035G1]
# 6853           1255U
# 6854    Apple M2 Max
# 6855     [i5, 1235U]
# Name: cpu_implementation_1, Length: 3719, dtype: object

# %%
d=d.apply(lambda x:x[0] if isinstance(x, list) else x)

# %%
d
# Out:
# 0                 i7
# 2                 i5
# 5                 i9
# 6                 i7
# 7             5900HX
#             ...
# 6850           5800H
# 6851              i5
# 6853           1255U
# 6854    Apple M2 Max
# 6855              i5
# Name: cpu_implementation_1, Length: 3719, dtype: object

# %%
d.value_counts().head(50)
# Out:
# i7                 801
# i5                 712
# i3                 161
# 5500U              112
# 5800H              106
# i9                  95
# 1135G7              88
# N4020               70
# 5600H               67
# 4565                60
# N4120               49
# 5625U               48
# 6800H               48
# 5700U               46
# 12700H              46
# N5030               43
# N4500               39
# N6000               39
# 5300U               37
# 5825U               35
# 1235U               32
# 1165G7              28
# 3250U               27
# 6900HX              24
# 5900HX              24
# 1115G4              23
# 11800H              23
# N5100               22
# N3350               21
# M2                  21
# 7505                19
# 4800H               19
# MT8183              19
# 1260P               16
# M2 Pro              16
# 1255U               16
# M1 Pro              15
# Apple M2 8-core     15
# 5650U               15
# 1035G1              14
# ...

# %%
data['cpu_type_1'].value_counts()
# Out:
# Intel Core i5                   564
# Intel Core i7                   528
# Intel® Core™ i7                 387
# Intel® Core™ i5                 330
# AMD Ryzen 7                     199
#                                ...
# AMD Athlon                        1
# MediaTek Kompanio 500 Series      1
# AMD Ryzen™ 9 PRO                  1
# Intel Pentium N                   1
# AMD A                             1
# Name: cpu_type_1, Length: 85, dtype: int64

# %%
d1=data['cpu_type_1'].apply(lambda x:x.split(' '))

# %%
# d1=d1.apply(lambda x:x)
d1
# Out:
# 0         [Intel, Core, i7]
# 2       [Intel®, Core™, i5]
# 5         [Intel, Core, i9]
# 6       [Intel®, Core™, i7]
# 7           [AMD, Ryzen, 9]
#                ...
# 6850        [AMD, Ryzen, 7]
# 6851      [Intel, Core, i5]
# 6853      [Intel, Core, i7]
# 6854       [Apple, M2, Max]
# 6855      [Intel, Core, i5]
# Name: cpu_type_1, Length: 3719, dtype: object

# %%
d='Mayasjc  naal jksd suidb is '
# d.index(' ')

# %%
# d=d[:d.index('')]
list_of_strings = ['mayank', 'zala', 'jello']
full_string = ' '.join(''.join(list_of_strings[1:]))
full_string
# Out:
# 'z a l a j e l l o'

# %%
f=d1.apply(lambda x:[x[0],' '.join(x[1:])]  if x[0].lower()=='amd' else x)
# list_of_strings[1] = ' '.join(list_of_strings[1:])

# %%
f
# Out:
# 0         [Intel, Core, i7]
# 2       [Intel®, Core™, i5]
# 5         [Intel, Core, i9]
# 6       [Intel®, Core™, i7]
# 7            [AMD, Ryzen 9]
#                ...
# 6850         [AMD, Ryzen 7]
# 6851      [Intel, Core, i5]
# 6853      [Intel, Core, i7]
# 6854       [Apple, M2, Max]
# 6855      [Intel, Core, i5]
# Name: cpu_type_1, Length: 3719, dtype: object

# %%
data['cpu_type_1']=data['cpu_type_1'].apply(lambda x:x.split(' '))

# %%
data
# Out:
#         id           cpu_type_1 cpu_implementation_1  cpu_number_of_cores_1  \
# 0     2881    [Intel, Core, i7]            i7-11800H                    8.0
# 2     6268  [Intel®, Core™, i5]             i5-1235U                   10.0
# 5      693    [Intel, Core, i9]            i9-12900H                   14.0
# 6     4165  [Intel®, Core™, i7]            i7-12700H                   14.0
# 7      830      [AMD, Ryzen, 9]               5900HX                    8.0
# ...    ...                  ...                  ...                    ...
# 6850  2957      [AMD, Ryzen, 7]                5800H                    8.0
# 6851  4462    [Intel, Core, i5]            i5-1035G1                    4.0
# 6853  3077    [Intel, Core, i7]                1255U                   10.0
# 6854  7011     [Apple, M2, Max]         Apple M2 Max                   12.0
# 6855  2789    [Intel, Core, i5]             i5-1235U                   10.0
#
# ...

# %%
# g=data.apply(lambda x:(x['cpu_implementation_1'].str.split('-') if x[0]=='i' else x)  if x['cpu_type']=='intel' else ( (x['cpu_type_1']) if(x['cpu_type']=='amd') else x)

# %%
data['cpu_type_1']=data['cpu_type_1'].apply(lambda x:[x[0],' '.join(x[1:])] if (x[0].lower()=='amd'or'apple') else x)

# %%
data
# Out:
#         id          cpu_type_1 cpu_implementation_1  cpu_number_of_cores_1  \
# 0     2881    [Intel, Core i7]            i7-11800H                    8.0
# 2     6268  [Intel®, Core™ i5]             i5-1235U                   10.0
# 5      693    [Intel, Core i9]            i9-12900H                   14.0
# 6     4165  [Intel®, Core™ i7]            i7-12700H                   14.0
# 7      830      [AMD, Ryzen 9]               5900HX                    8.0
# ...    ...                 ...                  ...                    ...
# 6850  2957      [AMD, Ryzen 7]                5800H                    8.0
# 6851  4462    [Intel, Core i5]            i5-1035G1                    4.0
# 6853  3077    [Intel, Core i7]                1255U                   10.0
# 6854  7011     [Apple, M2 Max]         Apple M2 Max                   12.0
# 6855  2789    [Intel, Core i5]             i5-1235U                   10.0
#
#       display_size__inch_1  memory_ram__gb_1 storage_type_1  \
# ...

# %%
data['cpu_implementation']=data['cpu_type_1'].apply(lambda x:x[1] if x[0].lower()=='amd' else(x[1] if x[0].lower()=='apple' else (x[1] if x[0].lower()=='intel' or x[0].lower()=='intel®' else x)))

# %%
data
# Out:
#         id          cpu_type_1 cpu_implementation_1  cpu_number_of_cores_1  \
# 0     2881    [Intel, Core i7]            i7-11800H                    8.0
# 2     6268  [Intel®, Core™ i5]             i5-1235U                   10.0
# 5      693    [Intel, Core i9]            i9-12900H                   14.0
# 6     4165  [Intel®, Core™ i7]            i7-12700H                   14.0
# 7      830      [AMD, Ryzen 9]               5900HX                    8.0
# ...    ...                 ...                  ...                    ...
# 6850  2957      [AMD, Ryzen 7]                5800H                    8.0
# 6851  4462    [Intel, Core i5]            i5-1035G1                    4.0
# 6853  3077    [Intel, Core i7]                1255U                   10.0
# 6854  7011     [Apple, M2 Max]         Apple M2 Max                   12.0
# 6855  2789    [Intel, Core i5]             i5-1235U                   10.0
#
#       display_size__inch_1  memory_ram__gb_1 storage_type_1  \
# ...

# %%
data['cpu_implementation'].value_counts().head(50)
# Out:
# Core i5                                 564
# Core i7                                 528
# Core™ i7                                387
# Core™ i5                                330
# Ryzen 7                                 199
# Ryzen 5                                 179
# Celeron                                 169
# Core i3                                 149
# Ryzen™ 5                                115
# Ryzen™ 7                                 78
# 3015Ce                                   66
# M                                        62
# Ryzen 3                                  61
# Core™ i3                                 58
# Core i9                                  56
# Celeron®                                 55
# Pentium                                  55
# Core™ i9                                 50
# Ryzen™ 3                                 45
# Pentium® Silver                          45
# 12th Generation Core i7                  36
# ...

# %%
# new_str = str.replace(u"u2122", '')

# %%
# data['cpu_implementation'].apply(lambda x:x.replace(u"u2122", ''))
data['cpu_implementation']=data['cpu_implementation'].apply(lambda x:'other' if isinstance(x, list) else x)

# %%
# use to remove the trade mark from data
import re
data['cpu_implementation']=data['cpu_implementation'].apply(lambda x:re.sub(r'[^\w\s]','',x))

# %%
d=data['cpu_type']
d2=data['cpu_implementation']

# %%
intel=[]
amd=[]
apple=[]
other=[]

# %%
for i in range(len(d)):
    if d[d.index[i]]=='intel':
        intel.append(d2[d2.index[i]])
    elif d[d.index[i]]=='amd':
        amd.append(d2[d2.index[i]])
    elif d[d.index[i]]=='apple':
        apple.append(d2[d2.index[i]])
    else:
        other.append(d2[d2.index[i]])

# %%
print(list(set(apple)))
# Out:
# ['M1', 'M1 Max', 'M2 Pro', 'M2 chip', 'M2 Max', 'M1chip', 'M', 'M2', 'M1 Pro']

# %%
intel=['11th Generation Core i7 Evo Platform', 'Core i3', 'Celeron N', 'Core M', '12th Generation Core i7', 'Core i5', '10th Generation Core i5', 'Xeon', 'Core i9', '10th Generation Core i3', '11th Generation Core i3', '10th Generation Core i7', '12th Generation Core i5', 'Pentium Gold', '12th Generation Core i3', 'Pentium', 'Core m3', '13th Generation Core i7', '11th Generation Core i7', 'Celeron', '12th Generation Core i9', 'Atom', 'Pentium Silver', '11th Generation Core i5', '12th Generation Core i7 Evo Platform', 'Pentium N', 'Core i7']
intel_a=['Core i7','Core i5','Celeron','Core i3','Core i9','Pentium','Pentium Silver','Celeron N']
apple_a=['M','M1 Pro','M1','M2 chip','M2 chip','M2','M2 Pro']
apple=['M2 Max', 'M2 chip', 'M1chip', 'M1 Max', 'M2 Pro', 'M1', 'M1 Pro', 'M', 'M2']
amd_a=['Ryzen 5','Ryzen 7','Ryzen 3','3015Ce','Ryzen 9']
amd=['Ryzen 9 5000 Series', 'Ryzen 3 PRO', 'A4', 'Ryzen 5 5000 Series', '3020E', 'Ryzen 7', 'Ryzen 5', 'A', 'Ryzen 7 Microsoft Surface Edition', 'Ryzen 7 5000 Series', '3015Ce', 'Ryzen 9', 'Athlon Silver', 'Ryzen 5 3000 Series', 'Ryzen 3', 'Ryzen 9 PRO', 'Ryzen 7 6000 Series', 'Ryzen 7 PRO', 'Ryzen 5 PRO', 'Ryzen 5 Microsoft Surface Edition', 'Athlon Gold']

def parse_cpu_implementation(text):
    if text in intel:
        if text in intel_a:
            return text
        else:
            return 'other intel cpu'
    elif text in amd:
        if text in amd_a:
            return text
        else:
            return 'other amd cpu'
    elif text in apple:
        if text in apple_a:
            return text
        else:
            return 'other apple cpu'
    else:
        return 'other'

# %%
data['cpu_implementation'].value_counts().head(60)
# Out:
# Core i7                                 915
# Core i5                                 894
# Ryzen 5                                 294
# Ryzen 7                                 277
# Celeron                                 224
# Core i3                                 207
# Core i9                                 106
# Ryzen 3                                 106
# 3015Ce                                   66
# M                                        62
# Pentium                                  55
# Ryzen 9                                  50
# Pentium Silver                           47
# other                                    41
# 12th Generation Core i7                  36
# 11th Generation Core i7                  24
# Celeron N                                24
# 11th Generation Core i5                  23
# Ryzen 7 5000 Series                      16
# M1 Pro                                   15
# Ryzen 7 PRO                              15
# ...

# %%
data['cpu_implementation']=data['cpu_implementation'].apply(parse_cpu_implementation)

# %%
data.head()
# Out:
#      id          cpu_type_1 cpu_implementation_1  cpu_number_of_cores_1  \
# 0  2881    [Intel, Core i7]            i7-11800H                    8.0
# 2  6268  [Intel®, Core™ i5]             i5-1235U                   10.0
# 5   693    [Intel, Core i9]            i9-12900H                   14.0
# 6  4165  [Intel®, Core™ i7]            i7-12700H                   14.0
# 7   830      [AMD, Ryzen 9]               5900HX                    8.0
#
#    display_size__inch_1  memory_ram__gb_1 storage_type_1  \
# 0                  17.3              16.0            SSD
# 2                  15.6               8.0            SSD
# 5                  16.0              32.0            SSD
# 6                  15.6              16.0            SSD
# 7                  16.0              32.0            SSD
#
#    storage_capacity__gb_1 design_color_name_1       price company    type  \
# 0                   512.0               Black  115101.760     msi   other
# ...

# %%
data=data.drop(columns=['cpu_type_1','cpu_implementation_1'])

# %%
data.head()
# Out:
#      id  cpu_number_of_cores_1  display_size__inch_1  memory_ram__gb_1  \
# 0  2881                    8.0                  17.3              16.0
# 2  6268                   10.0                  15.6               8.0
# 5   693                   14.0                  16.0              32.0
# 6  4165                   14.0                  15.6              16.0
# 7   830                    8.0                  16.0              32.0
#
#   storage_type_1  storage_capacity__gb_1 design_color_name_1       price  \
# 0            SSD                   512.0               Black  115101.760
# 2            SSD                   512.0            Metallic   71809.552
# 5            SSD                  2000.0                Gray  321397.440
# 6            SSD                  1000.0      Gray, Titanium  153861.440
# 7            SSD                  2000.0                Gray  271589.440
#
#   company    type cpu_type cpu_implementation
# 0     msi   other    intel            Core i7
# ...

# %%
data['cpu_number_of_cores_1'].value_counts()
sns.barplot(data['cpu_number_of_cores_1'],data['price'])
plt.xticks(rotation='vertical')
plt.show()
# Out:
# C:\Users\A to Z Infosys\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data['display_size__inch_1']=data['display_size__inch_1'].apply(lambda x:x if x in [15.60 ,14.00 ,17.30 ,13.30 ,16.00 ,11.60 ,13.50 ,15.00 ,16.10] else 'other')

# %%
sns.barplot(data['display_size__inch_1'],data['price'])
plt.xticks(rotation='vertical')
plt.show()
# Out:
# C:\Users\A to Z Infosys\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data['memory_ram__gb_1'].value_counts()
# Out:
# 16.0     1591
# 8.0      1389
# 4.0       395
# 32.0      298
# 64.0       17
# 12.0       13
# 512.0       6
# 2.0         3
# 128.0       2
# 256.0       2
# 40.0        2
# 24.0        1
# Name: memory_ram__gb_1, dtype: int64

# %%
sns.barplot(data['memory_ram__gb_1'],data['price'])
plt.xticks(rotation='vertical')
plt.show()
# Out:
# C:\Users\A to Z Infosys\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data['storage_type_1']=data['storage_type_1'].str.split(' ').apply(lambda x:x[0]).str.split(',').apply(lambda x:x[0])

# %%
sns.barplot(data['storage_type_1'],data['price'])
plt.xticks(rotation='vertical')
plt.show()
# Out:
# C:\Users\A to Z Infosys\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data['storage_capacity__gb_1']=data['storage_capacity__gb_1'].apply(lambda x:x if x in [512.0,256.0,1000.0,128.0,128.0,64.0,2000.0,32.0,1024.0] else 0)
data = data[data['storage_capacity__gb_1'] != 0.0]

# %%
# data=data.drop()

# %%
data['storage_capacity__gb_1'].value_counts()
# Out:
# 512.0     1437
# 256.0      911
# 1000.0     736
# 128.0      258
# 64.0       178
# 2000.0      75
# 32.0        68
# 1024.0      12
# Name: storage_capacity__gb_1, dtype: int64

# %%
sns.barplot(data['storage_capacity__gb_1'],data['price'])
plt.xticks(rotation='vertical')
plt.show()
# Out:
# C:\Users\A to Z Infosys\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data['design_color_name_1']=data['design_color_name_1'].apply(lambda x:x if x in ['Black','Silver','Gray','Platinum','Natuurlijk zilver','Blue','Black'] else 'other color')

# %%
sns.barplot(data['design_color_name_1'],data['price'])
plt.xticks(rotation='vertical')
plt.show()
# Out:
# C:\Users\A to Z Infosys\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Now data is ready to work

# %%
data['display_size__inch_1']=data['display_size__inch_1'].apply(lambda x:0.0 if x=='other' else x)

# %%
data=data.drop(columns='id')

# %%
data
# Out:
#       cpu_number_of_cores_1  display_size__inch_1  memory_ram__gb_1  \
# 0                       8.0                  17.3              16.0
# 2                      10.0                  15.6               8.0
# 5                      14.0                  16.0              32.0
# 6                      14.0                  15.6              16.0
# 7                       8.0                  16.0              32.0
# ...                     ...                   ...               ...
# 6850                    8.0                  16.1              16.0
# 6851                    4.0                  17.3               8.0
# 6853                   10.0                  17.3              16.0
# 6854                   12.0                  14.0              32.0
# 6855                   10.0                  15.6               8.0
#
#      storage_type_1  storage_capacity__gb_1 design_color_name_1        price  \
# ...

# %% [markdown]
# # Model Training

# %%
x=data.drop(columns='price')
y=np.log(data['price'])

# %%
x
# Out:
#       cpu_number_of_cores_1  display_size__inch_1  memory_ram__gb_1  \
# 0                       8.0                  17.3              16.0
# 2                      10.0                  15.6               8.0
# 5                      14.0                  16.0              32.0
# 6                      14.0                  15.6              16.0
# 7                       8.0                  16.0              32.0
# ...                     ...                   ...               ...
# 6850                    8.0                  16.1              16.0
# 6851                    4.0                  17.3               8.0
# 6853                   10.0                  17.3              16.0
# 6854                   12.0                  14.0              32.0
# 6855                   10.0                  15.6               8.0
#
#      storage_type_1  storage_capacity__gb_1 design_color_name_1 company  \
# 0               SSD                   512.0               Black     msi
# ...

# %%
y
# Out:
# 0       11.653572
# 2       11.181773
# 5       12.680434
# 6       11.943808
# 7       12.512047
#           ...
# 6850    11.412767
# 6851    11.026634
# 6853    11.557678
# 6854    12.666245
# 6855    11.296852
# Name: price, Length: 3675, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
x_train
# Out:
#       cpu_number_of_cores_1  display_size__inch_1  memory_ram__gb_1  \
# 1761                   12.0                  16.0              16.0
# 1512                    8.0                  13.3               8.0
# 6268                    8.0                  14.0              16.0
# 2729                   10.0                  15.6              16.0
# 1434                    4.0                  15.6              16.0
# ...                     ...                   ...               ...
# 6603                   14.0                  15.6              32.0
# 2727                   10.0                  15.0              16.0
# 4614                    6.0                  17.3               8.0
# 4664                   14.0                  17.3              16.0
# 6028                   10.0                  15.6               8.0
#
#      storage_type_1  storage_capacity__gb_1 design_color_name_1    company  \
# ...

# %%
data['display_size__inch_1'].value_counts()
# Out:
# 15.6    1322
# 14.0     842
# 17.3     386
# 13.3     266
# 16.0     232
# 0.0      217
# 11.6     133
# 13.5     115
# 15.0      97
# 16.1      65
# Name: display_size__inch_1, dtype: int64

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import accuracy_score,r2_score,mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
# one hot encoding
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[3,5,6,7,8,9])
],remainder='passthrough')

# %%
step1
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('col_tnf',
#                                  OneHotEncoder(drop='first', sparse=False),
#                                  [3, 5, 6, 7, 8, 9])])

# %%
# using linear regression
step2=LinearRegression()

pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])
pipe.fit(x_train,y_train)
y_predict=pipe.predict(x_test)
print("R2- ",r2_score(y_test,y_predict))
print("mean absolute error- ",mean_absolute_error(y_test,y_predict))
# Out:
# R2-  0.779124468383841
# mean absolute error-  0.2336871334971431
# C:\Users\A to Z Infosys\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
step2=KNeighborsRegressor(n_neighbors=3)
pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])
pipe.fit(x_train,y_train)
y_predict=pipe.predict(x_test)
print("R2- ",r2_score(y_test,y_predict))
print("mean absolute error- ",mean_absolute_error(y_test,y_predict))
# Out:
# R2-  0.8183004859233077
# mean absolute error-  0.21022040963319635
# C:\Users\A to Z Infosys\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
step2=RandomForestRegressor(
    n_estimators=100,
    random_state=3,
    max_samples=0.5,
    max_features=0.75,
    max_depth=15
)

pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])
pipe.fit(x_train,y_train)
y_predict=pipe.predict(x_test)
print("R2- ",r2_score(y_test,y_predict))
print("mean absolute error- ",mean_absolute_error(y_test,y_predict))
# Out:
# C:\Users\A to Z Infosys\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2-  0.8442172413725408
# mean absolute error-  0.19351005633477975

# %%
# Exporting the Unique value of each column to use in dropdown menu
import pickle
pickle.dump(data,open('data-dropdown_final.pkl','wb'))
pickle.dump(pipe,open('model_final.pkl','wb'))

# %%
data.columns
# Out:
# Index(['cpu_number_of_cores_1', 'display_size__inch_1', 'memory_ram__gb_1',
#        'storage_type_1', 'storage_capacity__gb_1', 'design_color_name_1',
#        'price', 'company', 'type', 'cpu_type', 'cpu_implementation'],
#       dtype='object')
